# %%
import pandas as pd
test = pd.read_csv('test.csv', encoding = 'iso-8859-1')
test.to_csv('test4.csv',encoding = 'utf-16')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-00963acebaf8> in <module>
#       1 import pandas as pd
# ----> 2 test = pd.read_csv('test.csv', encoding = 'iso-8859-1')
#
# ...

# %%
test.head()
# Out:
#                         Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                           Player     Nation        Pos        Age
# 1  Mikel Oyarzabal\Mikel-Oyarzabal     es ESP       FWMF         22
# 2        Mikel Merino\Mikel-Merino     es ESP         MF         23
# 3      Igor Zubeldia\Igor-Zubeldia     es ESP       MFDF         22
# 4      Joseba Zald£a\Joseba-Zaldua     es ESP         DF         27
#
#   Unnamed: 4 Standard Standard.1 Standard.2 Standard.3 Standard.4  ...  \
# 0        90s      Gls         Sh        SoT       SoT%      Sh/90  ...
# 1       33.9       10         57         18       31.6       1.68  ...
# 2       34.9        5         44         14       31.8       1.26  ...
# 3       29.3        0         14          1        7.1       0.48  ...
# 4       28.3        0          8          2       25.0       0.28  ...
#
#   Standard.7 Standard.8 Standard.9 Standard.10 Expected Expected.1 Expected.2  \
# ...

# %%
str1 = 'https://www.w3resource.com/python-exercises/string'
print(str1.rsplit('/', 1)[0])
print(str1.rsplit('-', 1)[0])
# Out:
# https://www.w3resource.com/python-exercises
# https://www.w3resource.com/python

# %%
split = pd.read_csv('new 1.csv')
split.head()
# Out:
#                             Player  Nation   Pos  Age   90s  Gls  Sh  SoT  \
# 0  Mikel Oyarzabal\Mikel-Oyarzabal  es ESP  FWMF   22  33.9   10  57   18
# 1        Mikel Merino\Mikel-Merino  es ESP    MF   23  34.9    5  44   14
# 2      Igor Zubeldia\Igor-Zubeldia  es ESP  MFDF   22  29.3    0  14    1
# 3      Joseba Zaldúa\Joseba-Zaldua  es ESP    DF   27  28.3    0   8    2
# 4  Martin Ødegaard\Martin-Odegaard  no NOR    MF   20  28.1    4  49   17
#
#    SoT%  Sh/90  ...  G/SoT  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0  31.6   1.68  ...   0.33   0   4      4  8.5   5.5     0.10   1.5      0.5
# 1  31.8   1.26  ...   0.36   1   0      0  2.9   2.9     0.06   2.1      2.1
# 2   7.1   0.48  ...   0.00   0   0      0  0.4   0.4     0.03  -0.4     -0.4
# 3  25.0   0.28  ...   0.00   0   0      0  0.2   0.2     0.02  -0.2     -0.2
# 4  34.7   1.75  ...   0.24   4   0      0  3.2   3.2     0.07   0.8      0.8
#
#    Matches
# 0  Matches
# 1  Matches
# 2  Matches
# ...

# %%
split['Player'] = split.astype(str)

split['Player']
# Out:
# 0           Mikel Oyarzabal\Mikel-Oyarzabal
# 1                 Mikel Merino\Mikel-Merino
# 2               Igor Zubeldia\Igor-Zubeldia
# 3               Joseba Zaldúa\Joseba-Zaldua
# 4           Martin Ødegaard\Martin-Odegaard
# 5               Nacho Monreal\Nacho-Monreal
# 6             Diego Llorente\Diego-Llorente
# 7         Robin Le Normand\Robin-Le-Normand
# 8                               Portu\Portu
# 9                   Álex Remiro\Alex-Remiro
# 10                Willian José\Willian-Jose
# 11          Aritz Elustondo\Aritz-Elustondo
# 12            Alexander Isak\Alexander-Isak
# 13      Miguel Ángel Moyá\Miguel-Angel-Moya
# 14              Adnan Januzaj\Adnan-Januzaj
# 15                  Aihen Muñoz\Aihen-Munoz
# 16              Ander Guevara\Ander-Guevara
# 17        Andoni Gorosabel\Andoni-Gorosabel
# 18        Martín Zubimendi\Martin-Zubimendi
# 19              Luca Sangalli\Luca-Sangalli
# 20      Ander Barrenetxea\Ander-Barrenetxea
# ...

# %%
ply=pd.read_csv('fifa20_data.csv')
ply.head()
# Out:
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                            Name  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2    Neymar da Silva Santos Jr.
# 3                     Jan Oblak
# 4               Kevin De Bruyne
#
#                                             Image    Country  Position  Age  \
# 0  https://cdn.sofifa.org/players/4/20/158023.png  Argentina  RW,CF,ST   32
# 1   https://cdn.sofifa.org/players/4/20/20801.png   Portugal     ST,LW   34
# 2  https://cdn.sofifa.org/players/4/20/190871.png     Brazil    LW,CAM   27
# 3  https://cdn.sofifa.org/players/4/20/200389.png   Slovenia        GK   26
# 4  https://cdn.sofifa.org/players/4/20/192985.png    Belgium    CAM,CM   28
#
# ...

# %%
split['Player']=split['Player'].str.split("\\").str[0]
split.head()
# Out:
#                             Player  Nation   Pos  Age   90s  Gls  Sh  SoT  \
# 0  Mikel Oyarzabal\Mikel-Oyarzabal  es ESP  FWMF   22  33.9   10  57   18
# 1        Mikel Merino\Mikel-Merino  es ESP    MF   23  34.9    5  44   14
# 2      Igor Zubeldia\Igor-Zubeldia  es ESP  MFDF   22  29.3    0  14    1
# 3      Joseba Zaldúa\Joseba-Zaldua  es ESP    DF   27  28.3    0   8    2
# 4  Martin Ødegaard\Martin-Odegaard  no NOR    MF   20  28.1    4  49   17
#
#    SoT%  Sh/90  ...  G/SoT  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0  31.6   1.68  ...   0.33   0   4      4  8.5   5.5     0.10   1.5      0.5
# 1  31.8   1.26  ...   0.36   1   0      0  2.9   2.9     0.06   2.1      2.1
# 2   7.1   0.48  ...   0.00   0   0      0  0.4   0.4     0.03  -0.4     -0.4
# 3  25.0   0.28  ...   0.00   0   0      0  0.2   0.2     0.02  -0.2     -0.2
# 4  34.7   1.75  ...   0.24   4   0      0  3.2   3.2     0.07   0.8      0.8
#
#    Matches
# 0  Matches
# 1  Matches
# 2  Matches
# ...

# %%
split[['First','Last']] = split['Player'].str.split("\\",expand=True,)
split.head()
# Out:
#                             Player  Nation   Pos  Age   90s  Gls  Sh  SoT  \
# 0  Mikel Oyarzabal\Mikel-Oyarzabal  es ESP  FWMF   22  33.9   10  57   18
# 1        Mikel Merino\Mikel-Merino  es ESP    MF   23  34.9    5  44   14
# 2      Igor Zubeldia\Igor-Zubeldia  es ESP  MFDF   22  29.3    0  14    1
# 3      Joseba Zaldúa\Joseba-Zaldua  es ESP    DF   27  28.3    0   8    2
# 4  Martin Ødegaard\Martin-Odegaard  no NOR    MF   20  28.1    4  49   17
#
#    SoT%  Sh/90  ...  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  Matches  \
# 0  31.6   1.68  ...   4      4  8.5   5.5     0.10   1.5      0.5  Matches
# 1  31.8   1.26  ...   0      0  2.9   2.9     0.06   2.1      2.1  Matches
# 2   7.1   0.48  ...   0      0  0.4   0.4     0.03  -0.4     -0.4  Matches
# 3  25.0   0.28  ...   0      0  0.2   0.2     0.02  -0.2     -0.2  Matches
# 4  34.7   1.75  ...   0      0  3.2   3.2     0.07   0.8      0.8  Matches
#
#              First             Last
# ...

# %%
flt = split[split['Pos'].str.contains('DF',case=False)]
flt.head()
# Out:
#                               Player  Nation   Pos  Age   90s  Gls  Sh  SoT  \
# 2        Igor Zubeldia\Igor-Zubeldia  es ESP  MFDF   22  29.3    0  14    1
# 3        Joseba Zaldúa\Joseba-Zaldua  es ESP    DF   27  28.3    0   8    2
# 5        Nacho Monreal\Nacho-Monreal  es ESP    DF   33  26.6    2  16    5
# 6      Diego Llorente\Diego-Llorente  es ESP    DF   25  25.9    1  10    4
# 7  Robin Le Normand\Robin-Le-Normand  fr FRA    DF   22  26.6    1  12    2
#
#    SoT%  Sh/90  ...  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  Matches  \
# 2   7.1   0.48  ...   0      0  0.4   0.4     0.03  -0.4     -0.4  Matches
# 3  25.0   0.28  ...   0      0  0.2   0.2     0.02  -0.2     -0.2  Matches
# 5  31.3   0.60  ...   0      0  2.3   2.3     0.14  -0.3     -0.3  Matches
# 6  40.0   0.39  ...   0      0  1.0   1.0     0.10   0.0      0.0  Matches
# 7  16.7   0.45  ...   0      0  0.9   0.9     0.08   0.1      0.1  Matches
#
#               First              Last
# ...

# %%
flt2= ply[ply['Position'].str.contains('RB',case=False)]
flt2.head()
# Out:
#                           Name  \
# 57              Joshua Kimmich
# 86       Daniel Carvajal Ramos
# 119  João Pedro Cavaco Cancelo
# 135                Kyle Walker
# 139    César Azpilicueta Tanco
#
#                                               Image   Country   Position  Age  \
# 57   https://cdn.sofifa.org/players/4/20/212622.png   Germany  RB,CM,CDM   24
# 86   https://cdn.sofifa.org/players/4/20/204963.png     Spain         RB   27
# 119  https://cdn.sofifa.org/players/4/20/210514.png  Portugal         RB   25
# 135  https://cdn.sofifa.org/players/4/20/188377.png   England         RB   29
# 139  https://cdn.sofifa.org/players/4/20/184432.png     Spain      RB,CB   29
#
#      Overall  Potential               Club      ID Height  ...     A/W  \
# 57        86         86  FC Bayern München  212622   5'9"  ...    High
# 86        85         85        Real Madrid  204963   5'8"  ...    High
# 119       84         84    Manchester City  210514   6'0"  ...    High
# ...
