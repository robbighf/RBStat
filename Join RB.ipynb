# %%
import pandas as pd
def_stat=pd.read_csv('RB_stat_def.csv').set_index('Rk')
#def_stat.set_index('Rk')
def_stat.head()
# Out:
#                                      Player   Nation   Pos           Squad  \
# Rk
# 1   Patrick van Aanholt\Patrick-van-Aanholt   nl NED    DF  Crystal Palace
# 2                     Max Aarons\Max-Aarons  eng ENG    DF    Norwich City
# 3         Yunis Abdelhamid\Yunis-Abdelhamid   ma MAR    DF           Reims
# 4     Suleiman Abdullahi\Suleiman-Abdullahi   ng NGA  FWMF    Union Berlin
# 5                   Mehdi Abeid\Mehdi-Abeid   dz ALG    MF          Nantes
#
#                   Comp   Age    Born   90s   Tkl  TklW  ...  Att 3rd.1  \
# Rk                                                      ...
# 1   eng Premier League  28.0  1990.0  27.9  1.83  1.15  ...       1.33
# 2   eng Premier League  19.0  2000.0  36.0  1.78  1.00  ...       1.72
# 3           fr Ligue 1  31.0  1987.0  28.0  2.18  1.32  ...       0.46
# 4        de Bundesliga  22.0  1996.0   1.7  0.59  0.59  ...       2.94
# 5           fr Ligue 1  26.0  1992.0  20.2  2.97  2.03  ...       3.12
#
# ...

# %%
def_stat[['First','Last']] = def_stat['Player'].str.split("\\",expand=True,)
def_stat.head()
#def_stat.to_csv('def_stat.csv',encoding = 'utf-8')
# Out:
#                                      Player   Nation   Pos           Squad  \
# Rk
# 1   Patrick van Aanholt\Patrick-van-Aanholt   nl NED    DF  Crystal Palace
# 2                     Max Aarons\Max-Aarons  eng ENG    DF    Norwich City
# 3         Yunis Abdelhamid\Yunis-Abdelhamid   ma MAR    DF           Reims
# 4     Suleiman Abdullahi\Suleiman-Abdullahi   ng NGA  FWMF    Union Berlin
# 5                   Mehdi Abeid\Mehdi-Abeid   dz ALG    MF          Nantes
#
#                   Comp   Age    Born   90s   Tkl  TklW  ...    Sh  ShSv  Pass  \
# Rk                                                      ...
# 1   eng Premier League  28.0  1990.0  27.9  1.83  1.15  ...  0.47  0.04  1.58
# 2   eng Premier League  19.0  2000.0  36.0  1.78  1.00  ...  0.83  0.06  1.94
# 3           fr Ligue 1  31.0  1987.0  28.0  2.18  1.32  ...  0.68  0.00  0.86
# 4        de Bundesliga  22.0  1996.0   1.7  0.59  0.59  ...  0.59  0.00  1.18
# ...

# %%
ply_pos=pd.read_csv('Fifa20_data.csv')
ply_pos.head()
# Out:
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                            Name  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2    Neymar da Silva Santos Jr.
# 3                     Jan Oblak
# 4               Kevin De Bruyne
#
#                                             Image    Country  Position  Age  \
# 0  https://cdn.sofifa.org/players/4/20/158023.png  Argentina  RW,CF,ST   32
# 1   https://cdn.sofifa.org/players/4/20/20801.png   Portugal     ST,LW   34
# 2  https://cdn.sofifa.org/players/4/20/190871.png     Brazil    LW,CAM   27
# 3  https://cdn.sofifa.org/players/4/20/200389.png   Slovenia        GK   26
# 4  https://cdn.sofifa.org/players/4/20/192985.png    Belgium    CAM,CM   28
#
# ...

# %%
ply_pos = ply_pos[['Name','Position']]
ply_pos.rename(columns={'Name':'First'},inplace=True)

# %%
ply_pos.head()
# Out:
#                           First  Position
# 0                  Lionel Messi  RW,CF,ST
# 1  C. Ronaldo dos Santos Aveiro     ST,LW
# 2    Neymar da Silva Santos Jr.    LW,CAM
# 3                     Jan Oblak        GK
# 4               Kevin De Bruyne    CAM,CM

# %%
ply_pos=ply_pos[ply_pos['Position'].str.contains('RB',case=False)]

# %%
ply_pos['Position']
# Out:
# 57       RB,CM,CDM
# 86              RB
# 119             RB
# 135             RB
# 139          RB,CB
#            ...
# 18512           RB
# 18523       CDM,RB
# 18524           RB
# 18539           RB
# 18543       RB,CDM
# Name: Position, Length: 2064, dtype: object

# %%
join_def_stat=pd.merge(def_stat,ply_pos,on='First')

# %%
join_def_stat.head()
join_def_stat.sort_values(by=['90s'])
# Out:
#                                             Player   Nation   Pos  \
# 139                  Chris Richards\Chris-Richards   us USA    DF
# 12                   Matthias Bader\Matthias-Bader   de GER    DF
# 17                 Raoul Bellanova\Raoul-Bellanova   it ITA    DF
# 49                       Thomas Doyle\Thomas-Doyle  eng ENG  MFFW
# 104                    Tariq Lamptey\Tariq-Lamptey  eng ENG    DF
# ..                                             ...      ...   ...
# 5    Trent Alexander-Arnold\Trent-Alexander-Arnold  eng ENG    DF
# 181                  Martin Valjent\Martin-Valjent   sk SVK    DF
# 145                    Amir Rrahmani\Amir-Rrahmani   xk KVX    DF
# 0                            Max Aarons\Max-Aarons  eng ENG    DF
# 120            Nikola Milenković\Nikola-Milenkovic   rs SRB    DF
#
#                Squad                Comp   Age    Born   90s    Tkl   TklW  \
# 139    Bayern Munich       de Bundesliga  19.0  2000.0   0.1   0.00   0.00
# ...

# %%
join_def_stat=join_def_stat[join_def_stat['Nation'].str.contains('Eng',case=False)]
join_def_stat.sort_values(by=['90s'])
join_def_stat.head()
# Out:
#                                            Player   Nation   Pos  \
# 0                           Max Aarons\Max-Aarons  eng ENG    DF
# 5   Trent Alexander-Arnold\Trent-Alexander-Arnold  eng ENG    DF
# 27                            Sam Byram\Sam-Byram  eng ENG    DF
# 49                      Thomas Doyle\Thomas-Doyle  eng ENG  MFFW
# 66                    Simon Francis\Simon-Francis  eng ENG    DF
#
#               Squad                Comp   Age    Born   90s   Tkl  TklW  ...  \
# 0      Norwich City  eng Premier League  19.0  2000.0  36.0  1.78  1.00  ...
# 5         Liverpool  eng Premier League  20.0  1998.0  35.3  1.64  0.71  ...
# 27     Norwich City  eng Premier League  25.0  1993.0  14.4  3.19  1.60  ...
# 49  Manchester City  eng Premier League  17.0  2001.0   0.2  0.00  0.00  ...
# 66      Bournemouth  eng Premier League  34.0  1985.0  10.8  1.57  1.11  ...
#
#     ShSv  Pass   Int  Tkl+Int   Clr   Err  Matches                   First  \
# ...

# %%
total_rows=len(join_def_stat.axes[0])
total_rows
# Out:
# 29

# %%
join_def_stat = join_def_stat[['First','TklW','Succ','Blocks','Int']]
join_def_stat.set_index('First',inplace=True)
join_def_stat
# Out:
#                         TklW  Succ  Blocks   Int
# First
# Max Aarons              1.00  3.67    2.78  0.56
# Trent Alexander-Arnold  0.71  3.71    1.50  0.96
# Sam Byram               1.60  5.14    3.47  1.39
# Thomas Doyle            0.00  5.00    0.00  0.00
# Simon Francis           1.11  2.69    2.69  0.65
# Ryan Fredericks         1.93  3.90    1.69  0.80
# Joe Gomez               0.67  2.69    1.12  0.85
# Mason Holgate           1.23  3.38    1.40  1.23
# Reece James             1.37  4.35    2.74  0.83
# Ben Johnson             1.33  2.00    2.67  1.33
# James Justin            1.70  5.09    2.23  0.71
# Jonjoe Kenny            1.29  4.34    1.89  0.93
# Tariq Lamptey           0.00  7.50    0.00  0.00
# Tariq Lamptey           0.46  2.62    2.00  1.38
# Matthew Lowton          1.41  3.53    2.47  0.94
# Ainsley Maitland-Niles  1.75  5.45    1.88  1.10
# Reece Oxford            1.67  4.05    1.43  0.95
# Adam Smith              1.32  4.87    2.46  1.01
# ...

# %%
test=join_def_stat.loc['Trent Alexander-Arnold']
test
# Out:
# TklW      0.71
# Succ      3.71
# Blocks    1.50
# Int       0.96
# Name: Trent Alexander-Arnold, dtype: float64

# %%
from soccerplots.radar_chart import Radar

params = list(join_def_stat.columns.values)

## range values
ranges = [(0.0, 5.0), (0.0,10.0), (0.06, 10.0), (0.0, 5.0)]

## parameter value
values = join_def_stat.loc['Trent Alexander-Arnold']
## instantiate object
radar = Radar()

## plot radar
fig, ax = radar.plot_radar(ranges=ranges, params=params, values=values, 
                                 radar_color=['#B6282F', '#FFFFFF'])
